# %% [markdown]
# ## Analyzing Europe's Data

# %% [markdown]
# <img src="http://wallpoper.com/images/00/40/48/35/europe-boats_00404835.jpg" width="800px">

# %% [markdown]
#  **Datasets Used for Analysis**

# %%
# for basic operations
import numpy as np 
import pandas as pd 

# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# for advanced visualizations
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import folium

# for providing path
import os
print(os.listdir("../input"))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ['pollution_2016.csv', 'env_satisfaction_2013.csv', 'life_satisfaction_2013.csv', 'trust_in_politics_2013.csv', 'median_income_2016.csv', 'trust_in_legal_2013.csv', 'job_satisfaction_2013.csv', 'make_ends_meet_2016.csv', 'crime_2016.csv', 'leisure_satisfaction_2013.csv', 'underemployment_2016.csv', 'close_relations_2015.csv', 'low_savings_2016.csv', 'weather.csv', 'life_expectancy_2016.csv', 'unemployment_2016.csv', 'trust_in_police_2013.csv', 'gdp_2016.csv', 'perceived_health_2016.csv', 'population_2011.csv', 'work_hours_2016.csv']

# %%
pollution = pd.read_csv('../input/pollution_2016.csv')
env_satisfaction = pd.read_csv('../input/env_satisfaction_2013.csv')
life_satisfaction = pd.read_csv('../input/life_satisfaction_2013.csv')
politics = pd.read_csv('../input/trust_in_politics_2013.csv')
income = pd.read_csv('../input/median_income_2016.csv')
legal = pd.read_csv('../input/trust_in_legal_2013.csv')
job_satisfaction = pd.read_csv('../input/job_satisfaction_2013.csv')
budget = pd.read_csv('../input/make_ends_meet_2016.csv')
crime = pd.read_csv('../input/crime_2016.csv')
leisure_satisfaction = pd.read_csv('../input/leisure_satisfaction_2013.csv')
underemployment = pd.read_csv('../input/underemployment_2016.csv')
close_relations = pd.read_csv('../input/close_relations_2015.csv')
low_savings = pd.read_csv('../input/low_savings_2016.csv')
weather = pd.read_csv('../input/weather.csv')
life_expectancy = pd.read_csv('../input/life_expectancy_2016.csv')
unemployment = pd.read_csv('../input/unemployment_2016.csv')
police = pd.read_csv('../input/trust_in_police_2013.csv')
gdp = pd.read_csv('../input/gdp_2016.csv')
health = pd.read_csv('../input/perceived_health_2016.csv')
population = pd.read_csv('../input/population_2011.csv')
work_hours = pd.read_csv('../input/work_hours_2016.csv')

# %% [markdown]
# <img src="https://images.adsttc.com/media/images/563c/b089/e58e/ce8c/e300/0095/original/Metropolis_Madrid.gif?1446817925" width="800px">

# %% [markdown]
# <img src="https://images.adsttc.com/media/images/563c/ac36/e58e/ce14/7c00/0095/original/San_Pedro_Vaticano.gif?1446816819" width="800px">

# %% [markdown]
# ## Geospatial Visualization

# %%
trace = [go.Choropleth(
               colorscale = 'YlOrRd',
               locationmode = 'country names',
               locations = underemployment['country'],
               text = underemployment['country'], 
               z = underemployment['med_income_underemp'],
               )]
layout = go.Layout(title = 'Under Employment in Police in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="573cffe8-e322-4be6-a066-d22624e9bd4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("573cffe8-e322-4be6-a066-d22624e9bd4e")) {
#                     Plotly.newPlot(
#                         '573cffe8-e322-4be6-a066-d22624e9bd4e',
#                         [{"colorscale": "YlOrRd", "locationmode": "country names", "locations": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "text": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "type": "choropleth", "uid": "2a2fd14f-3511-4c52-8e78-b9db6012ad8a", "z": [8.1, 14.6, 11.9, 5.5, 10.6, 6.7, 9.6, 10.7, 5.8, 17.2, 14.9, 11.4, 8.4, 13.0, 8.2, 18.2, 4.3, 12.8, 10.2, 6.6, 7.2, 7.3, 9.7, 7.7, 6.4, 9.1, 8.2, 8.5, 7.4, 6.5, 10.1, 11.3]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Under Employment in Police in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('573cffe8-e322-4be6-a066-d22624e9bd4e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = underemployment['country'],
             y = underemployment['med_income_underemp'],
             name = 'Under Employment',
             marker = dict(color = 'rgb(74, 47, 44)'),
)]
layout = go.Layout(title = 'Under Employment in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="91e9da21-f8bc-4b57-a753-acc5f52835fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("91e9da21-f8bc-4b57-a753-acc5f52835fa")) {
#                     Plotly.newPlot(
#                         '91e9da21-f8bc-4b57-a753-acc5f52835fa',
#                         [{"marker": {"color": "rgb(74, 47, 44)"}, "name": "Under Employment", "type": "bar", "uid": "9897b11b-fccd-4e14-94df-bf5e18aa60f2", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [8.1, 14.6, 11.9, 5.5, 10.6, 6.7, 9.6, 10.7, 5.8, 17.2, 14.9, 11.4, 8.4, 13.0, 8.2, 18.2, 4.3, 12.8, 10.2, 6.6, 7.2, 7.3, 9.7, 7.7, 6.4, 9.1, 8.2, 8.5, 7.4, 6.5, 10.1, 11.3]}],
#                         {"title": {"text": "Under Employment in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('91e9da21-f8bc-4b57-a753-acc5f52835fa');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Rainbow',
               locationmode = 'country names',
               locations = unemployment['country'],
               text = unemployment['country'], 
               z = unemployment['unemp_rate'],
               )]
layout = go.Layout(title = 'Unemployment Rate in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="dd7120be-2b25-4e0a-9a72-45f44d0dcf45" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("dd7120be-2b25-4e0a-9a72-45f44d0dcf45")) {
#                     Plotly.newPlot(
#                         'dd7120be-2b25-4e0a-9a72-45f44d0dcf45',
#                         [{"colorscale": "Rainbow", "locationmode": "country names", "locations": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "text": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "type": "choropleth", "uid": "a77aa399-0fa8-4ed8-9d91-a49f41b7ca4c", "z": [6.0, 7.8, 7.6, 5.0, 13.0, 4.0, 4.1, 6.2, 6.8, 23.6, 19.6, 8.8, 10.1, 13.1, 5.1, 8.4, 3.0, 11.7, 7.9, 6.3, 9.6, 4.7, 6.0, 4.7, 6.2, 11.2, 5.9, 7.0, 8.0, 9.7, 10.9, 4.8]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Unemployment Rate in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('dd7120be-2b25-4e0a-9a72-45f44d0dcf45');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = unemployment['country'],
             y = unemployment['unemp_rate'],
             name = 'Unemployment',
             marker = dict(color = 'rgb(4, 17, 54)'),
)]
layout = go.Layout(title = 'Unemployment in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="34bdf4d4-5d90-4b61-ab95-08354dfd7bd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("34bdf4d4-5d90-4b61-ab95-08354dfd7bd9")) {
#                     Plotly.newPlot(
#                         '34bdf4d4-5d90-4b61-ab95-08354dfd7bd9',
#                         [{"marker": {"color": "rgb(4, 17, 54)"}, "name": "Unemployment", "type": "bar", "uid": "5954e5b8-b94a-4691-af89-0b4fc245fbce", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [6.0, 7.8, 7.6, 5.0, 13.0, 4.0, 4.1, 6.2, 6.8, 23.6, 19.6, 8.8, 10.1, 13.1, 5.1, 8.4, 3.0, 11.7, 7.9, 6.3, 9.6, 4.7, 6.0, 4.7, 6.2, 11.2, 5.9, 7.0, 8.0, 9.7, 10.9, 4.8]}],
#                         {"title": {"text": "Unemployment in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('34bdf4d4-5d90-4b61-ab95-08354dfd7bd9');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Portland',
               locationmode = 'country names',
               locations = politics['country'],
               text = politics['country'], 
               z = politics['political_trust_rating'],
               )]
layout = go.Layout(title = 'Political Trust in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="9b44bcd6-4fe4-4981-9914-e73391d440cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9b44bcd6-4fe4-4981-9914-e73391d440cc")) {
#                     Plotly.newPlot(
#                         '9b44bcd6-4fe4-4981-9914-e73391d440cc',
#                         [{"colorscale": "Portland", "locationmode": "country names", "locations": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "text": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "type": "choropleth", "uid": "125935d7-b92c-497f-ae64-23efcb79ae34", "z": [4.6, 2.6, 3.7, 5.9, 4.9, 4.4, 3.2, 2.0, 1.9, 3.0, 2.8, 2.1, 2.6, 3.6, 4.5, 5.0, 4.5, 5.7, 5.5, 4.4, 3.5, 1.7, 4.8, 1.8, 3.5, 6.0, 5.5, 3.8, 3.7, 5.9, 6.6, 4.9]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Political Trust in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9b44bcd6-4fe4-4981-9914-e73391d440cc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = politics['country'],
             y = politics['political_trust_rating'],
             name = 'Under Employment',
             marker = dict(color = 'rgb(174, 54, 144)'),
)]
layout = go.Layout(title = 'Political Satisfaction in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="4b1670a5-dda5-4be7-99c4-06a0466d6937" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4b1670a5-dda5-4be7-99c4-06a0466d6937")) {
#                     Plotly.newPlot(
#                         '4b1670a5-dda5-4be7-99c4-06a0466d6937',
#                         [{"marker": {"color": "rgb(174, 54, 144)"}, "name": "Under Employment", "type": "bar", "uid": "a688b5ad-06b0-4748-a3ee-2d78d3592abe", "x": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "y": [4.6, 2.6, 3.7, 5.9, 4.9, 4.4, 3.2, 2.0, 1.9, 3.0, 2.8, 2.1, 2.6, 3.6, 4.5, 5.0, 4.5, 5.7, 5.5, 4.4, 3.5, 1.7, 4.8, 1.8, 3.5, 6.0, 5.5, 3.8, 3.7, 5.9, 6.6, 4.9]}],
#                         {"title": {"text": "Political Satisfaction in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('4b1670a5-dda5-4be7-99c4-06a0466d6937');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Earth',
               locationmode = 'country names',
               locations = police['country'],
               text = police['country'], 
               z = police['police_trust_rating'],
               )]
layout = go.Layout(title = 'Trust in Police in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="9f3a9fd6-c56c-4376-8a7b-e729ae6856ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9f3a9fd6-c56c-4376-8a7b-e729ae6856ad")) {
#                     Plotly.newPlot(
#                         '9f3a9fd6-c56c-4376-8a7b-e729ae6856ad',
#                         [{"colorscale": "Earth", "locationmode": "country names", "locations": ["Belgium", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Bulgaria", "Iceland", "Norway", "Switzerland", "Turkey", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta"], "text": ["Belgium", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Bulgaria", "Iceland", "Norway", "Switzerland", "Turkey", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta"], "type": "choropleth", "uid": "d8ff3493-5b51-42ee-9523-7c8094600682", "z": [6.1, 6.6, 7.2, 5.2, 5.4, 6.4, 5.5, 4.4, 8.2, 7.1, 6.4, 3.6, 7.7, 7.5, 7.4, 6.5, 4.9, 7.9, 6.4, 6.0, 6.9, 5.0, 5.4, 5.6, 6.10645161290323, 5.8, 4.7, 5.4, 6.0, 6.1, 5.7, 6.3]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Trust in Police in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9f3a9fd6-c56c-4376-8a7b-e729ae6856ad');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = police['country'],
             y = police['police_trust_rating'],
             name = 'Under Employment',
             marker = dict(color = 'rgb(7, 147, 244)'),
)]
layout = go.Layout(title = 'Satisfaction with Police in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="e5928e47-c4c0-4ed8-b706-0ac52963cce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e5928e47-c4c0-4ed8-b706-0ac52963cce0")) {
#                     Plotly.newPlot(
#                         'e5928e47-c4c0-4ed8-b706-0ac52963cce0',
#                         [{"marker": {"color": "rgb(7, 147, 244)"}, "name": "Under Employment", "type": "bar", "uid": "854b8fb2-75a0-44fa-a0d6-7baf19cce819", "x": ["Belgium", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Bulgaria", "Iceland", "Norway", "Switzerland", "Turkey", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta"], "y": [6.1, 6.6, 7.2, 5.2, 5.4, 6.4, 5.5, 4.4, 8.2, 7.1, 6.4, 3.6, 7.7, 7.5, 7.4, 6.5, 4.9, 7.9, 6.4, 6.0, 6.9, 5.0, 5.4, 5.6, 6.10645161290323, 5.8, 4.7, 5.4, 6.0, 6.1, 5.7, 6.3]}],
#                         {"title": {"text": "Satisfaction with Police in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('e5928e47-c4c0-4ed8-b706-0ac52963cce0');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Blackbody',
               locationmode = 'country names',
               locations = health['country'],
               text = health['country'], 
               z = health['prct_health_verygood'],
               )]
layout = go.Layout(title = 'Good Health in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="8c0f1950-516f-493d-b38a-195e067e698b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8c0f1950-516f-493d-b38a-195e067e698b")) {
#                     Plotly.newPlot(
#                         '8c0f1950-516f-493d-b38a-195e067e698b',
#                         [{"colorscale": "Blackbody", "locationmode": "country names", "locations": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "text": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "type": "choropleth", "uid": "3b54c79d-4d3f-4b15-8e0b-aceb8b4b8c2d", "z": [31.9, 29.8, 19.1, 33.2, 44.1, 18.6, 18.0, 26.5, 9.3, 45.0, 15.6, 20.2, 21.9, 25.5, 17.6, 41.7, 38.3, 10.5, 6.6, 23.4, 5.1, 22.3, 22.5, 28.8, 15.9, 8.7, 26.6, 29.0, 20.3, 22.4, 6.5, 30.8]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Good Health in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8c0f1950-516f-493d-b38a-195e067e698b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = go.Bar(
             x = health['country'],
             y = health['prct_health_verygood'],
             name = 'Very Good Health',
             marker = dict(color = 'rgb(10, 15, 20)'),
)
trace2 = go.Bar(
             x = health['country'],
             y = health['prct_health_good'],
             name = 'Good Health',
             marker = dict(color = 'rgb(170, 165, 160)'),
)
trace3 = go.Bar(
             x = health['country'],
             y = health['prct_health_fair'],
             name = 'Fair Health',
             marker = dict(color = 'rgb(100, 110, 120)'),
)
trace4 = go.Bar(
             x = health['country'],
             y = health['prct_health_bad'],
             name = 'Bad Health',
             marker = dict(color = 'rgb(70, 80, 90)'),
)
trace5 = go.Bar(
             x = health['country'],
             y = health['prct_health_verybad'],
             name = 'Very Bad Health',
             marker = dict(color = 'rgb(5, 10, 5)'),
)
data = [trace, trace2, trace3, trace4, trace5]
layout = go.Layout(title = 'Health in Europe',
                  barmode = 'relative')
fig = go.Figure(data = data, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="20b0b736-c70e-419c-b16c-df48608ba0c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("20b0b736-c70e-419c-b16c-df48608ba0c1")) {
#                     Plotly.newPlot(
#                         '20b0b736-c70e-419c-b16c-df48608ba0c1',
#                         [{"marker": {"color": "rgb(10, 15, 20)"}, "name": "Very Good Health", "type": "bar", "uid": "17efc733-19b8-4835-8c16-3db996229ed9", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [31.9, 29.8, 19.1, 33.2, 44.1, 18.6, 18.0, 26.5, 9.3, 45.0, 15.6, 20.2, 21.9, 25.5, 17.6, 41.7, 38.3, 10.5, 6.6, 23.4, 5.1, 22.3, 22.5, 28.8, 15.9, 8.7, 26.6, 29.0, 20.3, 22.4, 6.5, 30.8]}, {"marker": {"color": "rgb(170, 165, 160)"}, "name": "Good Health", "type": "bar", "uid": "1ec04f88-8fa6-44b5-9dd7-92c685d87013", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [38.3, 43.9, 46.7, 44.5, 34.6, 41.8, 47.2, 44.8, 43.6, 29.0, 56.9, 50.1, 44.5, 33.8, 42.0, 41.1, 37.7, 60.4, 36.8, 45.8, 42.1, 50.6, 53.4, 48.4, 42.7, 39.0, 43.9, 46.0, 44.2, 44.1, 62.3, 38.1]}, {"marker": {"color": "rgb(100, 110, 120)"}, "name": "Fair Health", "type": "bar", "uid": "8cfdfd41-21c2-4699-8212-dbe40d99e943", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [21.6, 17.0, 23.2, 17.8, 16.8, 27.9, 26.5, 21.1, 32.7, 15.6, 20.6, 23.8, 25.5, 22.1, 27.1, 13.7, 17.4, 21.4, 39.6, 21.2, 37.2, 23.9, 19.2, 15.1, 27.8, 36.4, 22.3, 19.2, 25.5, 21.8, 21.7, 22.2]}, {"marker": {"color": "rgb(70, 80, 90)"}, "name": "Bad Health", "type": "bar", "uid": "2f5970b6-10f6-451e-9e49-d8a07cb0ae88", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [6.4, 7.2, 8.7, 3.8, 3.8, 9.7, 6.9, 5.4, 12.5, 7.5, 5.5, 5.0, 7.1, 14.8, 10.4, 2.8, 5.0, 6.4, 14.2, 7.8, 12.6, 2.6, 4.2, 6.4, 11.0, 12.1, 6.0, 4.5, 8.2, 9.1, 8.3, 6.9]}, {"marker": {"color": "rgb(5, 10, 5)"}, "name": "Very Bad Health", "type": "bar", "uid": "fff42a6a-d644-426b-a1dd-c5dbaa4627d6", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [1.7, 2.0, 2.3, 0.7, 0.7, 2.0, 1.4, 2.2, 1.9, 2.8, 1.4, 0.9, 1.0, 3.8, 2.8, 0.8, 1.5, 1.3, 2.7, 1.8, 3.0, 0.5, 0.7, 1.3, 2.7, 3.8, 1.2, 1.2, 1.7, 2.6, 1.3, 1.9]}],
#                         {"barmode": "relative", "title": {"text": "Health in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('20b0b736-c70e-419c-b16c-df48608ba0c1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Picnic',
               locationmode = 'country names',
               locations = pollution['country'],
               text = pollution['country'], 
               z = pollution['prct_rpt_pollution'],
               )]
layout = go.Layout(title = 'Avg. Pollution in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="37cde3e5-41f6-415d-9120-756ad42ffa50" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("37cde3e5-41f6-415d-9120-756ad42ffa50")) {
#                     Plotly.newPlot(
#                         '37cde3e5-41f6-415d-9120-756ad42ffa50',
#                         [{"colorscale": "Picnic", "locationmode": "country names", "locations": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "text": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "type": "choropleth", "uid": "8277ea9b-fe05-4993-8edd-0cd18c2679e7", "z": [13.2, 15.1, 13.5, 6.8, 23.2, 9.9, 4.6, 19.6, 10.1, 14.1, 7.0, 15.1, 9.2, 17.2, 15.6, 16.1, 12.8, 30.2, 13.2, 10.7, 11.4, 13.1, 14.5, 15.9, 9.3, 7.2, 6.3, 9.0, 7.9, 6.8, 8.9, 24.5]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Avg. Pollution in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('37cde3e5-41f6-415d-9120-756ad42ffa50');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = pollution['country'],
             y = pollution['prct_rpt_pollution'],
             name = 'Pollution',
             marker = dict(color = 'rgb(220, 220, 220)'),
)]
layout = go.Layout(title = 'Pollution in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="bdf16b07-8fc5-4caa-a31b-5c513db2ed7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bdf16b07-8fc5-4caa-a31b-5c513db2ed7c")) {
#                     Plotly.newPlot(
#                         'bdf16b07-8fc5-4caa-a31b-5c513db2ed7c',
#                         [{"marker": {"color": "rgb(220, 220, 220)"}, "name": "Pollution", "type": "bar", "uid": "d4bca5eb-0402-4fec-8826-381ef8c85e23", "x": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "y": [13.2, 15.1, 13.5, 6.8, 23.2, 9.9, 4.6, 19.6, 10.1, 14.1, 7.0, 15.1, 9.2, 17.2, 15.6, 16.1, 12.8, 30.2, 13.2, 10.7, 11.4, 13.1, 14.5, 15.9, 9.3, 7.2, 6.3, 9.0, 7.9, 6.8, 8.9, 24.5]}],
#                         {"title": {"text": "Pollution in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('bdf16b07-8fc5-4caa-a31b-5c513db2ed7c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Blues',
               locationmode = 'country names',
               locations = weather['country'],
               text = weather['country'], 
               z = weather['avg_precipitation'],
               )]
layout = go.Layout(title = 'Avg. Precipitation in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="87ad8502-fae8-49cd-836e-e70d5f3c4305" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("87ad8502-fae8-49cd-836e-e70d5f3c4305")) {
#                     Plotly.newPlot(
#                         '87ad8502-fae8-49cd-836e-e70d5f3c4305',
#                         [{"colorscale": "Blues", "locationmode": "country names", "locations": ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "text": ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "type": "choropleth", "uid": "936a6d16-6fd8-4c9f-8387-73cb22ca07f2", "z": [39.3, 33.1, 24.7, 41.1, 15.4, 27.4, 23.9, 25.6, 21.9, 30.7, 29.4, 25.3, 22.7, 38.1, 40.8, 30.4, 23.2, 26.3, 32.4, 22.0, 29.7, 44.2, 24.6, 32.5, 24.7, 26.2, 49.1, 21.7, 22.6, 46.7, 25.7, 29.7]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Avg. Precipitation in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('87ad8502-fae8-49cd-836e-e70d5f3c4305');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = go.Bar(
             x = weather['country'],
             y = weather['avg_temp'],
             name = 'Average Temp.',
             marker = dict(color = 'rgb(250, 250, 200)'),
)
trace2 = go.Bar(
             x = weather['country'],
             y = weather['avg_high_temp'],
             name = 'Avg. High Temp',
             marker = dict(color = 'rgb(20, 20, 20)'),
)
trace3 = go.Bar(
             x = weather['country'],
             y = weather['avg_low_temp'],
             name = 'Avg. Low Temp',
             marker = dict(color = 'rgb(186, 200, 250)'),
)
trace4 = go.Bar(
             x = weather['country'],
             y = weather['avg_precipitation'],
             name = 'Avg. Precipitation',
             marker = dict(color = 'rgb(220, 190, 220)'),
)
df = [trace, trace2, trace3, trace4]
layout = go.Layout(title = 'Weather in Europe',
                  barmode = 'relative')
fig = go.Figure(data = df, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="5b3e0485-bff0-470d-9489-7d521438311a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5b3e0485-bff0-470d-9489-7d521438311a")) {
#                     Plotly.newPlot(
#                         '5b3e0485-bff0-470d-9489-7d521438311a',
#                         [{"marker": {"color": "rgb(250, 250, 200)"}, "name": "Average Temp.", "type": "bar", "uid": "b7fff559-28ea-4f43-96a8-cca40087fb89", "x": ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "y": [44.6, 48.8, 49.4, 55.1, 66.1, 44.5, 46.0, 41.9, 36.6, 52.3, 46.6, 62.5, 50.3, 38.5, 49.4, 56.3, 42.9, 43.4, 46.7, 65.7, 49.2, 39.8, 44.6, 60.4, 47.6, 43.2, 46.4, 60.0, 40.3, 42.5, 54.2, 48.8]}, {"marker": {"color": "rgb(20, 20, 20)"}, "name": "Avg. High Temp", "type": "bar", "uid": "e043fdba-594d-423c-9332-cbb2960269c5", "x": ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "y": [54.2, 55.5, 59.3, 62.3, 75.1, 51.4, 51.4, 48.4, 43.9, 60.5, 54.0, 70.1, 58.3, 43.1, 55.2, 63.8, 48.8, 49.6, 54.6, 72.3, 55.1, 44.1, 56.2, 68.3, 57.1, 53.0, 53.8, 69.3, 46.7, 50.8, 63.9, 55.3]}, {"marker": {"color": "rgb(186, 200, 250)"}, "name": "Avg. Low Temp", "type": "bar", "uid": "ab2a8cb7-a0dc-4e5b-b9b5-6419d14c8cb1", "x": ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "y": [37.4, 42.0, 43.4, 48.0, 57.5, 37.3, 41.6, 35.9, 31.3, 45.6, 40.5, 53.9, 42.7, 34.2, 44.0, 49.1, 38.2, 36.9, 41.2, 59.1, 43.7, 33.8, 33.8, 54.2, 41.1, 36.0, 38.7, 52.3, 33.6, 35.8, 44.6, 42.9]}, {"marker": {"color": "rgb(220, 190, 220)"}, "name": "Avg. Precipitation", "type": "bar", "uid": "7f84127e-364f-4ed7-9c18-4b9b98638fd3", "x": ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "y": [39.3, 33.1, 24.7, 41.1, 15.4, 27.4, 23.9, 25.6, 21.9, 30.7, 29.4, 25.3, 22.7, 38.1, 40.8, 30.4, 23.2, 26.3, 32.4, 22.0, 29.7, 44.2, 24.6, 32.5, 24.7, 26.2, 49.1, 21.7, 22.6, 46.7, 25.7, 29.7]}],
#                         {"barmode": "relative", "title": {"text": "Weather in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5b3e0485-bff0-470d-9489-7d521438311a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Viridis',
               locationmode = 'country names',
               locations = weather['country'],
               text = weather['country'], 
               z = weather['avg_temp'],
               )]
layout = go.Layout(title = 'Avg. Temperature in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="90d96be9-c3ec-4f0d-acdd-eecb91249b48" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("90d96be9-c3ec-4f0d-acdd-eecb91249b48")) {
#                     Plotly.newPlot(
#                         '90d96be9-c3ec-4f0d-acdd-eecb91249b48',
#                         [{"colorscale": "Viridis", "locationmode": "country names", "locations": ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "text": ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "type": "choropleth", "uid": "b3ac1980-5cca-407d-b01a-46d4bad8486f", "z": [44.6, 48.8, 49.4, 55.1, 66.1, 44.5, 46.0, 41.9, 36.6, 52.3, 46.6, 62.5, 50.3, 38.5, 49.4, 56.3, 42.9, 43.4, 46.7, 65.7, 49.2, 39.8, 44.6, 60.4, 47.6, 43.2, 46.4, 60.0, 40.3, 42.5, 54.2, 48.8]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Avg. Temperature in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('90d96be9-c3ec-4f0d-acdd-eecb91249b48');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Reds',
               locationmode = 'country names',
               locations = low_savings['country'],
               text = low_savings['country'], 
               z = low_savings['prct_low_savings'],
               )]
layout = go.Layout(title = 'Low Savings in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="702c6fdc-b343-47ca-be2d-bfe22216a4c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("702c6fdc-b343-47ca-be2d-bfe22216a4c1")) {
#                     Plotly.newPlot(
#                         '702c6fdc-b343-47ca-be2d-bfe22216a4c1',
#                         [{"colorscale": "Reds", "locationmode": "country names", "locations": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "text": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "type": "choropleth", "uid": "1405a803-b9bd-4e70-8171-0f0d0e9e809f", "z": [22.6, 25.9, 54.2, 21.0, 56.6, 32.1, 30.0, 24.5, 31.6, 53.6, 38.7, 29.4, 31.8, 57.7, 50.8, 45.3, 30.9, 40.4, 53.2, 21.9, 60.0, 20.8, 22.5, 18.1, 37.9, 38.3, 54.5, 20.7, 41.7, 37.9, 34.4, 38.0]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Low Savings in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('702c6fdc-b343-47ca-be2d-bfe22216a4c1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = low_savings['country'],
             y = low_savings['prct_low_savings'],
             name = 'Low Savings',
             marker = dict(color = 'rgb(250, 200, 190)'),
)]
layout = go.Layout(title = 'Low Savings in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="d8a1f6c1-44c9-4f02-ad10-f07025b4aa3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d8a1f6c1-44c9-4f02-ad10-f07025b4aa3c")) {
#                     Plotly.newPlot(
#                         'd8a1f6c1-44c9-4f02-ad10-f07025b4aa3c',
#                         [{"marker": {"color": "rgb(250, 200, 190)"}, "name": "Low Savings", "type": "bar", "uid": "103b89f4-8e05-467e-a43f-05fcedd072fb", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [22.6, 25.9, 54.2, 21.0, 56.6, 32.1, 30.0, 24.5, 31.6, 53.6, 38.7, 29.4, 31.8, 57.7, 50.8, 45.3, 30.9, 40.4, 53.2, 21.9, 60.0, 20.8, 22.5, 18.1, 37.9, 38.3, 54.5, 20.7, 41.7, 37.9, 34.4, 38.0]}],
#                         {"title": {"text": "Low Savings in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d8a1f6c1-44c9-4f02-ad10-f07025b4aa3c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Cividis',
               locationmode = 'country names',
               locations = life_expectancy['country'],
               text = life_expectancy['country'], 
               z = life_expectancy['life_expect'],
               )]
layout = go.Layout(title = 'Life Expectancy in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="758fe8cd-3888-4cd8-b574-640a8c706910" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("758fe8cd-3888-4cd8-b574-640a8c706910")) {
#                     Plotly.newPlot(
#                         '758fe8cd-3888-4cd8-b574-640a8c706910',
#                         [{"colorscale": "Cividis", "locationmode": "country names", "locations": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "text": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "type": "choropleth", "uid": "d940b3a9-e6fe-4214-9d18-ed5551d16805", "z": [81.8, 81.5, 74.9, 83.7, 82.7, 79.1, 81.0, 80.9, 78.0, 81.5, 83.5, 81.5, 82.7, 78.2, 76.2, 81.8, 82.2, 83.4, 74.9, 82.7, 74.9, 82.6, 81.7, 82.5, 78.0, 81.3, 75.3, 82.4, 81.2, 77.3, 78.1, 81.2]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "Life Expectancy in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('758fe8cd-3888-4cd8-b574-640a8c706910');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = life_expectancy['country'],
             y = life_expectancy['life_expect'],
             name = 'Life Expectancy',
             marker = dict(color = 'rgb(190, 220, 250)'),
)]
layout = go.Layout(title = 'Life Expectancy in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="20d0e8d2-c07f-4b6d-937e-d0da65d5063a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("20d0e8d2-c07f-4b6d-937e-d0da65d5063a")) {
#                     Plotly.newPlot(
#                         '20d0e8d2-c07f-4b6d-937e-d0da65d5063a',
#                         [{"marker": {"color": "rgb(190, 220, 250)"}, "name": "Life Expectancy", "type": "bar", "uid": "9bda76f1-2cb2-4c4c-8ce1-ad8c4e167887", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [81.8, 81.5, 74.9, 83.7, 82.7, 79.1, 81.0, 80.9, 78.0, 81.5, 83.5, 81.5, 82.7, 78.2, 76.2, 81.8, 82.2, 83.4, 74.9, 82.7, 74.9, 82.6, 81.7, 82.5, 78.0, 81.3, 75.3, 82.4, 81.2, 77.3, 78.1, 81.2]}],
#                         {"title": {"text": "Life Expectancy in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('20d0e8d2-c07f-4b6d-937e-d0da65d5063a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Earth',
               locationmode = 'country names',
               locations = leisure_satisfaction['country'],
               text = leisure_satisfaction['country'], 
               z = leisure_satisfaction['prct_leisure_satis_high'],
               )]
layout = go.Layout(title = 'High Leisure Satisfaction in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="cec996a1-ebc1-46af-af85-50d385a8256e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cec996a1-ebc1-46af-af85-50d385a8256e")) {
#                     Plotly.newPlot(
#                         'cec996a1-ebc1-46af-af85-50d385a8256e',
#                         [{"colorscale": "Earth", "locationmode": "country names", "locations": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "text": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "type": "choropleth", "uid": "35d0e04d-05a6-4b35-8926-fc780b81487b", "z": [35.0, 30.2, 25.8, 12.2, 21.5, 14.6, 24.3, 41.4, 24.2, 22.2, 29.1, 11.6, 21.2, 23.3, 24.5, 13.8, 24.0, 21.4, 22.0, 30.0, 15.4, 23.6, 18.9, 35.3, 27.8, 23.9, 18.0, 24.7, 26.6, 35.9, 33.2, 29.0]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "High Leisure Satisfaction in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('cec996a1-ebc1-46af-af85-50d385a8256e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = go.Bar(
             x = leisure_satisfaction['country'],
             y = leisure_satisfaction['prct_leisure_satis_high'],
             name = 'High Satisfaction',
             marker = dict(color = 'rgb(240, 240, 240)'),
)
trace2 = go.Bar(
             x = leisure_satisfaction['country'],
             y = leisure_satisfaction['prct_leisure_satis_med'],
             name = 'Medium Satisfaction',
             marker = dict(color = 'rgb(90, 30, 40)'),
)
trace3 = go.Bar(
             x = leisure_satisfaction['country'],
             y = leisure_satisfaction['prct_leisure_satis_low'],
             name = 'Low Satisfaction',
             marker = dict(color = 'rgb(138, 208, 138)'),
)

df = [trace, trace2, trace3]
layout = go.Layout(title = 'Leisure Satisfaction in Europe',
                  barmode = 'relative')
fig = go.Figure(data = df, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="ad38f160-1b78-499f-9b7e-ec8e6d844047" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ad38f160-1b78-499f-9b7e-ec8e6d844047")) {
#                     Plotly.newPlot(
#                         'ad38f160-1b78-499f-9b7e-ec8e6d844047',
#                         [{"marker": {"color": "rgb(240, 240, 240)"}, "name": "High Satisfaction", "type": "bar", "uid": "673b2c84-4f62-4e00-8c16-8147948af1c7", "x": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "y": [35.0, 30.2, 25.8, 12.2, 21.5, 14.6, 24.3, 41.4, 24.2, 22.2, 29.1, 11.6, 21.2, 23.3, 24.5, 13.8, 24.0, 21.4, 22.0, 30.0, 15.4, 23.6, 18.9, 35.3, 27.8, 23.9, 18.0, 24.7, 26.6, 35.9, 33.2, 29.0]}, {"marker": {"color": "rgb(90, 30, 40)"}, "name": "Medium Satisfaction", "type": "bar", "uid": "a1ce244e-9d81-4b16-b350-395b65398d41", "x": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "y": [43.0, 45.3, 46.7, 36.4, 60.6, 33.9, 44.1, 40.9, 42.5, 44.9, 42.3, 52.2, 49.0, 51.4, 42.1, 58.2, 48.0, 57.8, 52.4, 47.5, 49.4, 46.1, 75.2, 41.4, 42.3, 40.6, 59.6, 45.7, 44.0, 51.6, 44.9, 41.7]}, {"marker": {"color": "rgb(138, 208, 138)"}, "name": "Low Satisfaction", "type": "bar", "uid": "0d35aa37-1db2-4c47-a518-2918d7066bce", "x": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "y": [22.0, 24.5, 27.5, 51.5, 17.9, 51.5, 31.5, 17.7, 33.3, 33.0, 28.6, 36.2, 29.7, 25.2, 33.4, 28.0, 28.1, 20.8, 25.6, 22.5, 35.2, 30.3, 5.9, 23.3, 29.9, 35.5, 22.4, 29.6, 29.4, 12.5, 21.9, 29.3]}],
#                         {"barmode": "relative", "title": {"text": "Leisure Satisfaction in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ad38f160-1b78-499f-9b7e-ec8e6d844047');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Rainbow',
               locationmode = 'country names',
               locations = job_satisfaction['country'],
               text = job_satisfaction['country'], 
               z = job_satisfaction['prct_job_satis_high'],
               )]
layout = go.Layout(title = 'High Job Satisfaction in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="30b62ff3-12fa-4e14-9fdc-eaf9c2b1e458" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("30b62ff3-12fa-4e14-9fdc-eaf9c2b1e458")) {
#                     Plotly.newPlot(
#                         '30b62ff3-12fa-4e14-9fdc-eaf9c2b1e458',
#                         [{"colorscale": "Rainbow", "locationmode": "country names", "locations": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "text": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "type": "choropleth", "uid": "a8b4ff74-b603-49c4-9079-918bd542c91b", "z": [42.3, 39.1, 36.6, 18.3, 23.0, 16.1, 29.6, 44.4, 25.0, 26.6, 28.3, 14.0, 19.4, 20.0, 25.6, 20.2, 28.2, 25.8, 29.6, 30.4, 23.0, 27.2, 22.9, 42.2, 32.0, 24.5, 20.4, 29.1, 29.2, 40.8, 34.5, 28.0]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "High Job Satisfaction in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('30b62ff3-12fa-4e14-9fdc-eaf9c2b1e458');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = go.Bar(
             x = job_satisfaction['country'],
             y = job_satisfaction['prct_job_satis_high'],
             name = 'job_satisfaction',
             marker = dict(color = 'orange'),
)
trace2 = go.Bar(
             x = job_satisfaction['country'],
             y = job_satisfaction['prct_job_satis_med'],
             name = 'job_satisfaction',
             marker = dict(color = 'lightgreen'),
)
trace3 = go.Bar(
             x = job_satisfaction['country'],
             y = job_satisfaction['prct_job_satis_low'],
             name = 'job_satisfaction',
             marker = dict(color = 'pink'),
)
df = [trace, trace2, trace3]
layout = go.Layout(title = 'Job Satisfaction in Europe',
                   barmode = 'relative')
fig = go.Figure(data = df, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="c91731dc-90aa-4661-a780-100208a87569" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c91731dc-90aa-4661-a780-100208a87569")) {
#                     Plotly.newPlot(
#                         'c91731dc-90aa-4661-a780-100208a87569',
#                         [{"marker": {"color": "orange"}, "name": "job_satisfaction", "type": "bar", "uid": "3a1c38f0-62ca-448b-9a6b-de44de17cbff", "x": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "y": [42.3, 39.1, 36.6, 18.3, 23.0, 16.1, 29.6, 44.4, 25.0, 26.6, 28.3, 14.0, 19.4, 20.0, 25.6, 20.2, 28.2, 25.8, 29.6, 30.4, 23.0, 27.2, 22.9, 42.2, 32.0, 24.5, 20.4, 29.1, 29.2, 40.8, 34.5, 28.0]}, {"marker": {"color": "lightgreen"}, "name": "job_satisfaction", "type": "bar", "uid": "48d3bbcf-9e14-4f59-84aa-5fcb455cd2d5", "x": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "y": [48.0, 53.6, 54.9, 39.5, 68.5, 36.1, 51.4, 46.4, 50.7, 55.1, 51.7, 48.3, 59.1, 64.7, 49.0, 62.2, 51.8, 56.9, 55.4, 55.1, 55.7, 59.7, 71.7, 47.6, 48.2, 50.4, 61.6, 51.5, 48.5, 54.6, 52.5, 49.6]}, {"marker": {"color": "pink"}, "name": "job_satisfaction", "type": "bar", "uid": "4853c32a-527b-4d83-a818-3313bb533f70", "x": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "y": [9.6, 7.2, 8.5, 42.2, 8.5, 47.7, 19.0, 9.2, 24.3, 18.4, 20.0, 37.7, 21.5, 15.4, 25.4, 17.6, 20.0, 17.3, 15.0, 14.5, 21.3, 13.1, 5.4, 10.2, 19.8, 25.1, 18.0, 19.3, 22.3, 4.7, 13.0, 22.4]}],
#                         {"barmode": "relative", "title": {"text": "Job Satisfaction in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c91731dc-90aa-4661-a780-100208a87569');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Greys',
               locationmode = 'country names',
               locations = gdp['country'],
               text = gdp['country'], 
               z = gdp['gdp'],
               )]
layout = go.Layout(title = 'GDP in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="f9042c8d-11ba-42e2-a720-a24a98761e30" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f9042c8d-11ba-42e2-a720-a24a98761e30")) {
#                     Plotly.newPlot(
#                         'f9042c8d-11ba-42e2-a720-a24a98761e30',
#                         [{"colorscale": "Greys", "locationmode": "country names", "locations": ["Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy"], "text": ["Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy"], "type": "choropleth", "uid": "3a195f4d-8059-4533-b788-aa5b16a94029", "z": [18490.2, 25037.7, 38849.4, 53303.0, 113903.8, 10344.1, 708337.0, 356237.6, 426547.5, 186480.5, 170393.6, 40357.2, 81226.1, 216073.0, 463147.5, 2403382.6, 18646.1, 335747.5, 605753.7, 780224.9, 424660.3, 48128.6, 176370.1, 282089.9, 3159750.0, 21682.6, 273238.2, 176487.9, 1118743.0, 2228568.0, 46639.5, 1689824.0]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "GDP in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f9042c8d-11ba-42e2-a720-a24a98761e30');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = gdp['country'],
             y = gdp['gdp'],
             name = 'GDP',
             marker = dict(color = 'rgb(96, 76, 56)'),
)]
layout = go.Layout(title = 'GDP in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="dddd84aa-038d-4881-9103-10c7df82bfc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("dddd84aa-038d-4881-9103-10c7df82bfc8")) {
#                     Plotly.newPlot(
#                         'dddd84aa-038d-4881-9103-10c7df82bfc8',
#                         [{"marker": {"color": "rgb(96, 76, 56)"}, "name": "GDP", "type": "bar", "uid": "6023e332-7f2b-49fa-8e42-1321ed8b3e3e", "x": ["Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy"], "y": [18490.2, 25037.7, 38849.4, 53303.0, 113903.8, 10344.1, 708337.0, 356237.6, 426547.5, 186480.5, 170393.6, 40357.2, 81226.1, 216073.0, 463147.5, 2403382.6, 18646.1, 335747.5, 605753.7, 780224.9, 424660.3, 48128.6, 176370.1, 282089.9, 3159750.0, 21682.6, 273238.2, 176487.9, 1118743.0, 2228568.0, 46639.5, 1689824.0]}],
#                         {"title": {"text": "GDP in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('dddd84aa-038d-4881-9103-10c7df82bfc8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Blackbody',
               locationmode = 'country names',
               locations = crime['country'],
               text = crime['country'], 
               z = crime['prct_rpt_crime'],
               )]

layout = go.Layout(title = '%age of Reported Crime in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="7bb8c2a8-7aef-494c-bdc7-af5cd63b485d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7bb8c2a8-7aef-494c-bdc7-af5cd63b485d")) {
#                     Plotly.newPlot(
#                         '7bb8c2a8-7aef-494c-bdc7-af5cd63b485d',
#                         [{"colorscale": "Blackbody", "locationmode": "country names", "locations": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "text": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "type": "choropleth", "uid": "477470cf-522c-455a-a10b-20139d717102", "z": [12.4, 13.4, 25.0, 10.9, 9.8, 11.7, 14.1, 8.4, 9.2, 11.8, 10.3, 6.5, 14.8, 3.0, 9.7, 9.9, 2.2, 14.7, 3.4, 12.2, 10.0, 10.4, 16.9, 4.6, 5.6, 7.8, 14.1, 12.7, 8.5, 6.9, 10.7, 16.8]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "%age of Reported Crime in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7bb8c2a8-7aef-494c-bdc7-af5cd63b485d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = crime['country'],
             y = crime['prct_rpt_crime'],
             name = 'Crime',
             marker = dict(color = 'rgb(90, 20, 50)'),
)]
layout = go.Layout(title = 'Crime in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="bcd81804-8a9c-47de-8b8c-fd22b74b61c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bcd81804-8a9c-47de-8b8c-fd22b74b61c2")) {
#                     Plotly.newPlot(
#                         'bcd81804-8a9c-47de-8b8c-fd22b74b61c2',
#                         [{"marker": {"color": "rgb(90, 20, 50)"}, "name": "Crime", "type": "bar", "uid": "d19e7522-993b-493a-b68a-37f10f5b49bf", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [12.4, 13.4, 25.0, 10.9, 9.8, 11.7, 14.1, 8.4, 9.2, 11.8, 10.3, 6.5, 14.8, 3.0, 9.7, 9.9, 2.2, 14.7, 3.4, 12.2, 10.0, 10.4, 16.9, 4.6, 5.6, 7.8, 14.1, 12.7, 8.5, 6.9, 10.7, 16.8]}],
#                         {"title": {"text": "Crime in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('bcd81804-8a9c-47de-8b8c-fd22b74b61c2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Portland',
               locationmode = 'country names',
               locations = close_relations['country'],
               text = close_relations['country'], 
               z = close_relations['prct_close_relat'],
               )]

layout = go.Layout(title = '%age of Close Relations in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="4bdb5bae-d6e7-4c21-89ef-5989aded1f13" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4bdb5bae-d6e7-4c21-89ef-5989aded1f13")) {
#                     Plotly.newPlot(
#                         '4bdb5bae-d6e7-4c21-89ef-5989aded1f13',
#                         [{"colorscale": "Portland", "locationmode": "country names", "locations": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "text": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "type": "choropleth", "uid": "5b56ba4b-e4c0-44ff-91ad-c43cdf099c7e", "z": [92.2, 95.3, 98.1, 95.5, 96.7, 92.8, 96.2, 96.2, 96.9, 93.1, 94.5, 86.8, 97.0, 91.8, 96.8, 87.1, 97.2, 96.1, 90.9, 95.8, 95.9, 90.4, 95.6, 96.4, 97.9, 98.1, 97.3, 93.1, 96.4, 97.1, 95.7, 95.9]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "%age of Close Relations in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('4bdb5bae-d6e7-4c21-89ef-5989aded1f13');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Bar(
             x = close_relations['country'],
             y = close_relations['prct_close_relat'],
             name = 'Close Relations',
             marker = dict(color = 'rgb(90, 120, 50)'),
)]
layout = go.Layout(title = 'Close Relations in Europe')
fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="1ad35bcf-c135-49cf-8471-35a8f3caccbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1ad35bcf-c135-49cf-8471-35a8f3caccbe")) {
#                     Plotly.newPlot(
#                         '1ad35bcf-c135-49cf-8471-35a8f3caccbe',
#                         [{"marker": {"color": "rgb(90, 120, 50)"}, "name": "Close Relations", "type": "bar", "uid": "7296c31b-6333-43a5-811c-a285a4b42cff", "x": ["Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "y": [92.2, 95.3, 98.1, 95.5, 96.7, 92.8, 96.2, 96.2, 96.9, 93.1, 94.5, 86.8, 97.0, 91.8, 96.8, 87.1, 97.2, 96.1, 90.9, 95.8, 95.9, 90.4, 95.6, 96.4, 97.9, 98.1, 97.3, 93.1, 96.4, 97.1, 95.7, 95.9]}],
#                         {"title": {"text": "Close Relations in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1ad35bcf-c135-49cf-8471-35a8f3caccbe');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'Jet',
               locationmode = 'country names',
               locations = population['country'],
               text = population['country'], 
               z = population['prct_yng_adt_pop'],
               )]

layout = go.Layout(title = '%age of Young population in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,))

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="5f2ac2d0-6655-4eea-b4cf-8dea1f7db609" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5f2ac2d0-6655-4eea-b4cf-8dea1f7db609")) {
#                     Plotly.newPlot(
#                         '5f2ac2d0-6655-4eea-b4cf-8dea1f7db609',
#                         [{"colorscale": "Jet", "locationmode": "country names", "locations": ["Belgium", "Bulgaria", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Czechia", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Denmark", "Poland", "Portugal", "Romania", "Germany", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "text": ["Belgium", "Bulgaria", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Czechia", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Denmark", "Poland", "Portugal", "Romania", "Germany", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "type": "choropleth", "uid": "ca7e0b12-8e5a-4f1a-bf8e-bd558913e052", "z": [18.4851460433477, 18.4325765115954, 19.688363056266898, 20.6013349397843, 17.604416155416, 16.6743314398887, 18.527500485112398, 18.5512623547541, 15.4749732744415, 18.862489172677602, 23.3226282027637, 20.442857825964502, 20.526780812037998, 18.9406522456197, 18.3451221961619, 20.590659077406603, 18.269979122586697, 18.6775435197109, 18.0820044066965, 21.9158084735625, 17.0740447661458, 18.775327519261502, 17.105589842993, 18.308799822845604, 21.908599460889302, 18.7139599901475, 19.3862924193189, 19.942316013787398, 21.5933146573033, 19.5865463817537, 18.4457868857281, 18.7139599901475]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "%age of Young population in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5f2ac2d0-6655-4eea-b4cf-8dea1f7db609');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = go.Bar(
             x = life_expectancy['country'],
             y = life_expectancy['life_expect'],
             name = 'Population',
             marker = dict(color = 'rgb(8, 19, 20)'),
)
trace = go.Bar(
             x = life_expectancy['country'],
             y = life_expectancy['life_expect'],
             name = 'Young Population',
             marker = dict(color = 'rgb(135, 135, 135)'),
)
df = [trace, trace2]

layout = go.Layout(title = 'Population in Europe',
                  barmode = 'relative')
fig = go.Figure(data = df, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="20f40c44-56e5-4ab5-a131-b7544087653c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("20f40c44-56e5-4ab5-a131-b7544087653c")) {
#                     Plotly.newPlot(
#                         '20f40c44-56e5-4ab5-a131-b7544087653c',
#                         [{"marker": {"color": "rgb(135, 135, 135)"}, "name": "Young Population", "type": "bar", "uid": "06f97211-b2fa-4b34-bf6a-adc04b33a5d9", "x": ["Austria", "Belgium", "Bulgaria", "Switzerland", "Cyprus", "Czechia", "Germany", "Denmark", "Estonia", "Greece", "Spain", "Finland", "France", "Croatia", "Hungary", "Ireland", "Iceland", "Italy", "Lithuania", "Luxembourg", "Latvia", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey", "United Kingdom"], "y": [81.8, 81.5, 74.9, 83.7, 82.7, 79.1, 81.0, 80.9, 78.0, 81.5, 83.5, 81.5, 82.7, 78.2, 76.2, 81.8, 82.2, 83.4, 74.9, 82.7, 74.9, 82.6, 81.7, 82.5, 78.0, 81.3, 75.3, 82.4, 81.2, 77.3, 78.1, 81.2]}, {"marker": {"color": "lightgreen"}, "name": "job_satisfaction", "type": "bar", "uid": "1df897a4-8020-4b64-bf10-a122ee5cc29b", "x": ["Iceland", "Norway", "Switzerland", "Turkey", "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom"], "y": [48.0, 53.6, 54.9, 39.5, 68.5, 36.1, 51.4, 46.4, 50.7, 55.1, 51.7, 48.3, 59.1, 64.7, 49.0, 62.2, 51.8, 56.9, 55.4, 55.1, 55.7, 59.7, 71.7, 47.6, 48.2, 50.4, 61.6, 51.5, 48.5, 54.6, 52.5, 49.6]}],
#                         {"barmode": "relative", "title": {"text": "Population in Europe"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('20f40c44-56e5-4ab5-a131-b7544087653c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace = [go.Choropleth(
               colorscale = 'YlOrRd',
               locationmode = 'country names',
               locations = population['country'],
               text = population['country'], 
               z = population['total_pop'],
               )]

layout = go.Layout(title = 'population in European Countries',
                  geo = go.layout.Geo(
                       scope = 'europe',
                       showcountries = True,)
                  )

fig = go.Figure(data = trace, layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="5422442a-8ce7-41c7-9aea-84a73040c6e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5422442a-8ce7-41c7-9aea-84a73040c6e8")) {
#                     Plotly.newPlot(
#                         '5422442a-8ce7-41c7-9aea-84a73040c6e8',
#                         [{"colorscale": "YlOrRd", "locationmode": "country names", "locations": ["Belgium", "Bulgaria", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Czechia", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Denmark", "Poland", "Portugal", "Romania", "Germany", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "text": ["Belgium", "Bulgaria", "Estonia", "Ireland", "Greece", "Spain", "France", "Croatia", "Italy", "Czechia", "Cyprus", "Latvia", "Lithuania", "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Denmark", "Poland", "Portugal", "Romania", "Germany", "Slovenia", "Slovakia", "Finland", "Sweden", "United Kingdom", "Iceland", "Norway", "Switzerland", "Turkey"], "type": "choropleth", "uid": "3b8d7c14-803b-4acc-ba56-502a84eff056", "z": [11000638, 7364570, 1294455, 4574888, 10816286, 46815910, 64933400, 4284889, 59433744, 10436560, 840407, 2070371, 3043429, 512353, 9937628, 417432, 16655799, 8401940, 5560628, 38044565, 10562178, 20121641, 80219695, 2050189, 5397036, 5375276, 9482855, 63182180, 315556, 4979954, 7954662, 7954662]}],
#                         {"geo": {"scope": "europe", "showcountries": true}, "title": {"text": "population in European Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5422442a-8ce7-41c7-9aea-84a73040c6e8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ### Thanks for reading the kernel, please, stay tuned there is more to come.
